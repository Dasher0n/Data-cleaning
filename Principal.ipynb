# %%
from google.colab import drive
import os
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = "/content/drive/My Drive/Cuestionarios"
files = os.listdir(folder_path)
excel_files = [f for f in files if f.endswith('.xlsx') or f.endswith('.xls')]

print(excel_files)  # Para verificar qué archivos encontró
# Out:
# ['CaminoProfesionalMAC1.xlsx', 'Finanzas Transparentes (Respuestas).xlsx', 'Habilidades de MAC (respuestas).xlsx', 'Copia de Perfil Académico (respuestas).xlsx', 'Impacto del Horario en el Desempeño y Bienestar de los Estudiantes de Minería de Datos (respuestas).xlsx', 'Copia de Uso de Tecnología y Redes Sociales.xlsx', 'Copia de Rendimiento académico (respuestas).xlsx']

# %%
# Crear un diccionario donde cada archivo tendrá su propio DataFrame
dataframes = {}

for file in excel_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_excel(file_path, header=0)  # Lee la primera fila como encabezado
    dataframes[file] = df  # Guarda el DataFrame en el diccionario

# Mostrar los primeros registros de cada DataFrame
for file, df in dataframes.items():
    print(f"📂 Archivo: {file}")
    print(df.head(), "\n")
# Out:
# 📂 Archivo: CaminoProfesionalMAC1.xlsx
#            Marca temporal  Número de cuenta  \
# 0 2025-02-25 20:30:04.522         422075345
# 1 2025-02-26 03:56:02.340         318104263
# 2 2025-02-28 00:26:52.421         422068044
# 3 2025-02-28 17:14:19.785         317237748
# 4 2025-02-28 17:35:49.834         421087105
#
#   ¿Cuál es tu mayor preocupación al terminar tus estudios?  \
# 0                                              Comer
# 1                              No encontrar trabajo
# 2       quedarme sin casa ni posibilidad de alimento
# 3               No llegar a conseguir un buen empleo
# 4                                   no tener trabajo
#
#   ¿Qué factores influyen más en tu decisión sobre qué camino seguir después de egresar?  \
# 0            El dinero y la felicidad principalmente
# 1                     Si voy a tener un buen sueldo
# 2                       oportunidades que aparezcan
# 3             Mi familia y que esté cerca de mi casa
# ...
